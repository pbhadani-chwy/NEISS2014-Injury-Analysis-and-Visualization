# %%
# importing all the necessary library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reading the dataset into a dataframe alias df
df = pd.read_csv('NEISS2014.csv')

# %%
# displaying the top 5 rows of the data for checking
df.head()
# Out:
#    CPSC Case # trmt_date  psu  weight stratum  age     sex         race  \
# 0    141200216  10/23/14   63  99.704       M   21  Female  None listed
# 1    140117851    1/4/14   63  81.576       M   62  Female        White
# 2    150144993   8/17/14   63  99.704       M   21  Female  None listed
# 3    150230176   7/27/14   63  99.704       M   30  Female  None listed
# 4    141220717    9/8/14   63  99.704       M   16    Male  None listed
#
#   race_other  diag diag_other  body_part  disposition  location  fmv  prod1  \
# 0        NaN    62        NaN         75            1         1    0    679
# 1        NaN    57        NaN         79            1         1    0   1807
# 2        NaN    57        NaN         83            1         0    0   1333
# 3        NaN    64        NaN         79            1         1    0   4076
# 4        NaN    57        NaN         82            1         0    0   1893
#
#     prod2                                          narrative
# ...

# %%
# code to draw scatter plot with age on the x-axis and diagnosis on the y-axis
df.plot.scatter(x='age',y='diag')

# %%
# code for renaming the column name and filtering out records with age greater than 110
df.rename(columns={'body_part':'Code'},inplace=True)
df_age = df[df['age']<=110]

# %%
df_age.head()
# Out:
#    CPSC Case # trmt_date  psu  weight stratum  age     sex         race  \
# 0    141200216  10/23/14   63  99.704       M   21  Female  None listed
# 1    140117851    1/4/14   63  81.576       M   62  Female        White
# 2    150144993   8/17/14   63  99.704       M   21  Female  None listed
# 3    150230176   7/27/14   63  99.704       M   30  Female  None listed
# 4    141220717    9/8/14   63  99.704       M   16    Male  None listed
#
#   race_other  diag diag_other  Code  disposition  location  fmv  prod1  \
# 0        NaN    62        NaN    75            1         1    0    679
# 1        NaN    57        NaN    79            1         1    0   1807
# 2        NaN    57        NaN    83            1         0    0   1333
# 3        NaN    64        NaN    79            1         1    0   4076
# 4        NaN    57        NaN    82            1         0    0   1893
#
#     prod2                                          narrative
# ...

# %%
# performing groupby clause on the column 'code'
df_bodyparts = df_age.groupby('Code',as_index=False)

# %%
# performing aggregation on the grouped column to find the frequency
df_count = df_bodyparts.count()

# %%
df_count.head()
# Out:
#    Code  CPSC Case #  trmt_date   psu  weight  stratum   age   sex  race  \
# 0     0          414        414   414     414      414   414   414   414
# 1    30         2653       2653  2653    2653     2653  2653  2653  2653
# 2    31         3824       3824  3824    3824     3824  3824  3824  3824
# 3    32         1529       1529  1529    1529     1529  1529  1529  1529
# 4    33         2499       2499  2499    2499     2499  2499  2499  2499
#
#    race_other  diag  diag_other  disposition  location   fmv  prod1  prod2  \
# 0          22   414           0          414       414   414    414     29
# 1         140  2653         430         2653      2653  2653   2653    257
# 2         209  3824        1354         3824      3824  3824   3824    518
# 3          88  1529         165         1529      1529  1529   1529    137
# 4         162  2499         160         2499      2499  2499   2499    266
#
#    narrative
# 0        414
# 1       2653
# 2       3824
# 3       1529
# ...

# %%
# apply sort method to sort the data in descending order
df_sort = df_count.sort_values(['CPSC Case #'],ascending=False)

# %%
df_sort
# Out:
#     Code  CPSC Case #  trmt_date   psu  weight  stratum   age   sex  race  \
# 10    75         8614       8614  8614    8614     8614  8614  8614  8614
# 13    79         5694       5694  5694    5694     5694  5694  5694  5694
# 23    92         5558       5558  5558    5558     5558  5558  5558  5558
# 11    76         5076       5076  5076    5076     5076  5076  5076  5076
# 2     31         3824       3824  3824    3824     3824  3824  3824  3824
# 8     37         3756       3756  3756    3756     3756  3756  3756  3756
# 6     35         3605       3605  3605    3605     3605  3605  3605  3605
# 16    82         3288       3288  3288    3288     3288  3288  3288  3288
# 17    83         3029       3029  3029    3029     3029  3029  3029  3029
# 1     30         2653       2653  2653    2653     2653  2653  2653  2653
# 4     33         2499       2499  2499    2499     2499  2499  2499  2499
# 7     36         2146       2146  2146    2146     2146  2146  2146  2146
# ...

# %%
# Sliced the first 2 column so that the join operation is less expensive
df_sliced = df_sort[['Code','CPSC Case #']]

# %%
# fetched top 3 rows from the sliced data
df_sliced[:3]
# Out:
#     Code  CPSC Case #
# 10    75         8614
# 13    79         5694
# 23    92         5558

# %%
# fetched the botton 3 rows from the sliced data
df_sliced[len(df_sliced)-4:]
# Out:
#     Code  CPSC Case #
# 0      0          414
# 20    87          311
# 9     38          282
# 18    84            2

# %%
# merged the data with the diagnosis dataset to fetch the injury name
df_merge=pd.merge(df_sliced,df_bodypart_data)

# %%
#Display top 3 injuries
df_merge[:3]['BodyPart']
# Out:
# 0            Head
# 1    Trunk, lower
# 2          Finger
# Name: BodyPart, dtype: object

# %%
# display bottom 3 injuries
df_merge[len(df_merge)-5:]['BodyPart']
# Out:
# 21        Arm, upper
# 22          Internal
# 23      Not Recorded
# 24      Pubic region
# 25    25-50% of body
# Name: BodyPart, dtype: object

# %%
df_bodypart_data = pd.read_csv('BodyParts.csv')

# %%
df_bodypart_data
# Out:
#           BodyPart  Code
# 0       Arm, lower    33
# 1       Arm, upper    80
# 2            Ankle    37
# 3              Ear    94
# 4            Elbow    32
# 5          Eyeball    77
# 6             Face    76
# 7           Finger    92
# 8             Foot    83
# 9             Hand    82
# 10            Head    75
# 11        Internal     0
# 12            Knee    35
# 13      Leg, lower    36
# 14      Leg, upper    81
# 15           Mouth    88
# 16            Neck    89
# 17    Pubic region    38
# 18        Shoulder    30
# 19             Toe    93
# 20    Trunk, lower    79
# 21    Trunk, upper    31
# 22           Wrist    34
# 23  25-50% of body    84
# 24    >50% of body    85
# 25    Not Recorded    87

# %%
freq_data
# Out:
# 0    75    9891
# 76    5786
# 92    5783
# Name: body_pa...
# 1    87    390
# 38    286
# 84      4
# Name: body_part,...
# dtype: object
